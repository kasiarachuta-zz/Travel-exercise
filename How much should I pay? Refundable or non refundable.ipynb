# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# I import the file with data

flights = pd.read_csv("BOS_CUN_trips1M.csv",)

flights.head()
# Out:
#                                           messageid  tripindex    received  \
# 0  f4f57b70aaf2f56600000141d88ccbb0294a88500186aea5         12  1382317607
# 1  f4f57b70aaf2f56600000141d88ccbb0294a88500186aea5         11  1382317607
# 2  f4f57b70aaf2f56600000141d88ccbb0294a88500186aea5         10  1382317607
# 3  f4f57b70aaf2f56600000141d88ccbb0294a88500186aea5          9  1382317607
# 4  f4f57b70aaf2f56600000141d88ccbb0294a88500186aea5          8  1382317607
#
#   currency   total     tax  surcharge source merchant majorcarrierid  \
# 0      USD  631.45  123.45        0.0  Sabre      TCY             US
# 1      USD  632.95  124.95        0.0  Sabre      TCY             US
# 2      USD  620.95  124.95        0.0  Sabre      TCY             B6
# 3      USD  632.95  124.95        0.0  Sabre      TCY             US
# 4      USD  565.95  124.95        0.0  Sabre      TCY             US
#
#       ...      refundable triptimestamp  receiveddate  received_odate  \
# 0     ...           False    1382317607      20131021      2013-10-20
# 1     ...           False    1382317607      20131021      2013-10-20
# 2     ...           False    1382317607      20131021      2013-10-20
# 3     ...           False    1382317607      20131021      2013-10-20
# 4     ...           False    1382317607      20131021      2013-10-20
#
#    departure_odate  return_ddate  los2  departure_dow  return_dow includes_sns
# 0       2014-03-14    2014-03-22     8              5           6            1
# 1       2014-03-14    2014-03-22     8              5           6            1
# 2       2014-03-14    2014-03-22     8              5           6            1
# 3       2014-03-14    2014-03-22     8              5           6            1
# 4       2014-03-14    2014-03-22     8              5           6            1
#
# [5 rows x 31 columns]

# %%
# I want to look at refundable flights first.

refundableflights = flights[flights['refundable'] == True]
refundableflights.head()
# Out:
#                                              messageid  tripindex    received  \
# 861   2c89c1ab745aec26000001410e399ab3aa9fe4728648ad8b         45  1378923158
# 947   3dc7cac49ef4382f000001410d1a5a260697a02b899615e0         37  1378904332
# 1020  42e64275e7bb0edd000001410d102090ecb3e2ded758ba6f         17  1378903662
# 1448  b54624dc6c91bc1e00000141e5685bb04257f803208eafb6         35  1382533323
# 1450  b54624dc6c91bc1e00000141e5685bb04257f803208eafb6         33  1382533323
#
#      currency    total     tax  surcharge source merchant majorcarrierid  \
# 861       USD  1251.57  116.57        0.0  Sabre      TCY             AM
# 947       USD   930.57  116.57        0.0  Sabre      TCY             AM
# 1020      USD   930.57  116.57        0.0  Sabre      TCY             AM
# 1448      USD  1495.15  112.15        0.0  Sabre      TCY             AM
# 1450      USD   980.15  126.15        0.0  Sabre      TCY             AM
#
#          ...      refundable triptimestamp  receiveddate  received_odate  \
# 861      ...            True    1378923158      20130911      2013-09-11
# 947      ...            True    1378904332      20130911      2013-09-11
# 1020     ...            True    1378903662      20130911      2013-09-11
# 1448     ...            True    1382533323      20131023      2013-10-23
# 1450     ...            True    1382533323      20131023      2013-10-23
#
#       departure_odate  return_ddate  los2  departure_dow  return_dow  \
# 861        2014-07-10    2014-07-18     8              4           5
# 947        2013-09-22    2013-09-29     7              0           0
# 1020       2013-10-11    2013-10-19     8              5           6
# 1448       2014-04-19    2014-04-26     7              6           6
# 1450       2014-04-19    2014-04-26     7              6           6
#
#      includes_sns
# 861             1
# 947             1
# 1020            1
# 1448            1
# 1450            1
#
# [5 rows x 31 columns]

# %%
# I now want to visualise the price spread of the refundable tickets.

sns.boxplot(refundableflights['total'], vert=False)
# Out:
# /Users/katarzynarachuta/anaconda/lib/python2.7/site-packages/seaborn/categorical.py:2125: UserWarning: The boxplot API has been changed. Attempting to adjust your arguments for the new API (which might not work). Please update your code. See the version 0.6 release notes for more info.
#   warnings.warn(msg, UserWarning)

# %%
# I can see that 75% of the refundable tickets are below $2,4000.

# %%
# I now run quick statistics on the refundable ticket prices.

refundableflights = refundableflights['total'].describe()

refundableflights = pd.DataFrame(refundableflights)

refundableflights
# Out:
#              total
# count  7924.000000
# mean   1145.334387
# std     408.931065
# min     466.170000
# 25%     826.950000
# 50%    1089.150000
# 75%    1436.570000
# max    3794.570000

# %%
# Now I want to look at the non-refundable flights.

nrefundableflights = flights[flights['refundable'] == False]
nrefundableflights.head()
# Out:
#                                           messageid  tripindex    received  \
# 0  f4f57b70aaf2f56600000141d88ccbb0294a88500186aea5         12  1382317607
# 1  f4f57b70aaf2f56600000141d88ccbb0294a88500186aea5         11  1382317607
# 2  f4f57b70aaf2f56600000141d88ccbb0294a88500186aea5         10  1382317607
# 3  f4f57b70aaf2f56600000141d88ccbb0294a88500186aea5          9  1382317607
# 4  f4f57b70aaf2f56600000141d88ccbb0294a88500186aea5          8  1382317607
#
#   currency   total     tax  surcharge source merchant majorcarrierid  \
# 0      USD  631.45  123.45        0.0  Sabre      TCY             US
# 1      USD  632.95  124.95        0.0  Sabre      TCY             US
# 2      USD  620.95  124.95        0.0  Sabre      TCY             B6
# 3      USD  632.95  124.95        0.0  Sabre      TCY             US
# 4      USD  565.95  124.95        0.0  Sabre      TCY             US
#
#       ...      refundable triptimestamp  receiveddate  received_odate  \
# 0     ...           False    1382317607      20131021      2013-10-20
# 1     ...           False    1382317607      20131021      2013-10-20
# 2     ...           False    1382317607      20131021      2013-10-20
# 3     ...           False    1382317607      20131021      2013-10-20
# 4     ...           False    1382317607      20131021      2013-10-20
#
#    departure_odate  return_ddate  los2  departure_dow  return_dow includes_sns
# 0       2014-03-14    2014-03-22     8              5           6            1
# 1       2014-03-14    2014-03-22     8              5           6            1
# 2       2014-03-14    2014-03-22     8              5           6            1
# 3       2014-03-14    2014-03-22     8              5           6            1
# 4       2014-03-14    2014-03-22     8              5           6            1
#
# [5 rows x 31 columns]

# %%
# I now want to visualise the price spread of the non-refundable tickets.

sns.boxplot(nrefundableflights['total'], vert=False)

# %%
# I can see that 75% of the non-refundable flights are below $1,250.
# Similarly as above, I'm running the quick statistics.

nrefundableflights = nrefundableflights['total'].describe()

nrefundableflights = pd.DataFrame(nrefundableflights)

nrefundableflights
# Out:
#               total
# count  1.194521e+06
# mean   6.711629e+02
# std    2.749562e+02
# min    3.203700e+02
# 25%    4.713700e+02
# 50%    5.893700e+02
# 75%    7.894500e+02
# max    6.523740e+03

# %%
# Now I'm going to produce the two box plots side by side to allow for comparison.

sns.boxplot(flights['refundable'], flights['total'])

# %%
'''As expect, the refundable flights are more expensive. However, I am surprised by the fact that the
non-refundable flights have quite a lot of expenisve outliers.'''
