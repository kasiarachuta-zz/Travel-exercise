# %%
import pandas as pd
import numpy as np

# %%
# I import the file with data

flights = pd.read_csv("BOS_CUN_trips1M.csv",)

flights.head()
# Out:
#                                           messageid  tripindex    received  \
# 0  f4f57b70aaf2f56600000141d88ccbb0294a88500186aea5         12  1382317607
# 1  f4f57b70aaf2f56600000141d88ccbb0294a88500186aea5         11  1382317607
# 2  f4f57b70aaf2f56600000141d88ccbb0294a88500186aea5         10  1382317607
# 3  f4f57b70aaf2f56600000141d88ccbb0294a88500186aea5          9  1382317607
# 4  f4f57b70aaf2f56600000141d88ccbb0294a88500186aea5          8  1382317607
#
#   currency   total     tax  surcharge source merchant majorcarrierid  \
# 0      USD  631.45  123.45        0.0  Sabre      TCY             US
# 1      USD  632.95  124.95        0.0  Sabre      TCY             US
# 2      USD  620.95  124.95        0.0  Sabre      TCY             B6
# 3      USD  632.95  124.95        0.0  Sabre      TCY             US
# 4      USD  565.95  124.95        0.0  Sabre      TCY             US
#
#       ...      refundable triptimestamp  receiveddate  received_odate  \
# ...

# %%
# I first look at the economy class.

economy = flights[flights['cabinclass'] == 'E']

economy.head()

# 1201004 rows × 31 columns
# Out:
#                                           messageid  tripindex    received  \
# 0  f4f57b70aaf2f56600000141d88ccbb0294a88500186aea5         12  1382317607
# 1  f4f57b70aaf2f56600000141d88ccbb0294a88500186aea5         11  1382317607
# 2  f4f57b70aaf2f56600000141d88ccbb0294a88500186aea5         10  1382317607
# 3  f4f57b70aaf2f56600000141d88ccbb0294a88500186aea5          9  1382317607
# 4  f4f57b70aaf2f56600000141d88ccbb0294a88500186aea5          8  1382317607
#
#   currency   total     tax  surcharge source merchant majorcarrierid  \
# 0      USD  631.45  123.45        0.0  Sabre      TCY             US
# 1      USD  632.95  124.95        0.0  Sabre      TCY             US
# 2      USD  620.95  124.95        0.0  Sabre      TCY             B6
# 3      USD  632.95  124.95        0.0  Sabre      TCY             US
# 4      USD  565.95  124.95        0.0  Sabre      TCY             US
#
#       ...      refundable triptimestamp  receiveddate  received_odate  \
# ...

# %%
# I then find quick stats of the economy flights. I am only interested in the 'total' column.

economy.describe()
# Out:
#           tripindex      received         total           tax  surcharge  \
# count  1.201004e+06  1.201004e+06  1.201004e+06  1.201004e+06  1201004.0
# mean   2.226551e+02  1.380625e+09  6.735797e+02  1.209828e+02        0.0
# std    7.984064e+02  1.410170e+06  2.724485e+02  1.169243e+01        0.0
# min    0.000000e+00  1.378080e+09  3.203700e+02  6.390000e+01        0.0
# 25%    1.000000e+01  1.379423e+09  4.719500e+02  1.153700e+02        0.0
# 50%    2.300000e+01  1.380729e+09  5.909500e+02  1.223700e+02        0.0
# 75%    3.900000e+01  1.381845e+09  7.933700e+02  1.249500e+02        0.0
# max    7.115000e+03  1.383005e+09  4.278770e+03  3.525500e+02        0.0
#
#           departure        return  outbounddurationminutes  outboundstops  \
# count  1.201004e+06  1.201004e+06             1.201004e+06   1.201004e+06
# mean   1.389352e+09  1.390013e+09             4.524196e+02   9.936661e-01
# std    5.881052e+06  5.909464e+06             1.407824e+02   3.783729e-01
# ...

# %%
'''I can see that for an economy flight, we won't pay more than ~$4278, with the mean value being $673 
and median being $590'''
# Out:
# "I can see that for an economy flight, we won't pay more than ~$4278, with the mean value being $673 \nand median being $590"

# %%
# I now want to look at business class flights

business = flights[flights['cabinclass'] == 'B']

business.head()

# 1041 rows × 31 columns
# Out:
#                                               messageid  tripindex  \
# 20173  11d548da24b2a342000001414e7f330828c6951ee8d33c5a        424
# 20174  11d548da24b2a342000001414e7f330828c6951ee8d33c5a        425
# 23629  3248dfa1a07f76fe000001416dce75480166920c4c89ca56        988
# 23631  3248dfa1a07f76fe000001416dce75480166920c4c89ca56        986
# 23635  3248dfa1a07f76fe000001416dce75480166920c4c89ca56        982
#
#          received currency    total     tax  surcharge   source merchant  \
# 20173  1380001461      USD   599.27  119.27        0.0  Amadeus       FL
# 20174  1380001461      USD   599.27  119.27        0.0  Amadeus       FL
# 23629  1380526749      USD  1240.37  101.37        0.0  Amadeus       UA
# 23631  1380526749      USD  1081.37  101.37        0.0  Amadeus       UA
# 23635  1380526749      USD   975.37  101.37        0.0  Amadeus       UA
#
#       majorcarrierid     ...      refundable triptimestamp  receiveddate  \
# ...

# %%
# Again, I run quick statistics.

business.describe()
# Out:
#          tripindex      received        total          tax  surcharge  \
# count  1041.000000  1.041000e+03  1041.000000  1041.000000     1041.0
# mean    990.464938  1.380719e+09   786.415043   115.852123        0.0
# std    1219.597421  1.380953e+06   245.655838     7.621238        0.0
# min       6.000000  1.378374e+09   562.570000   101.370000        0.0
# 25%     223.000000  1.379373e+09   608.850000   110.950000        0.0
# 50%     493.000000  1.381140e+09   659.180000   115.370000        0.0
# 75%    1293.000000  1.381823e+09   892.170000   123.450000        0.0
# max    7052.000000  1.382991e+09  1657.950000   166.230000        0.0
#
#           departure        return  outbounddurationminutes  outboundstops  \
# count  1.041000e+03  1.041000e+03              1041.000000    1041.000000
# mean   1.387213e+09  1.388103e+09               608.973103       1.050913
# std    5.716262e+06  5.734929e+06               250.448228       0.267290
# ...

# %%
'''For a business flight, the mean flight price is $786 and the median is $659 so I should expect to pay something around that'''
# Out:
# 'For a business flight, the mean flight price is $786 and the median is $659 so I should expect to pay something around that'

# %%
# Finally, I look at first class flights.

first = flights[flights['cabinclass'] == 'F']

first.head()

# 276 rows × 31 columns
# Out:
#                                               messageid  tripindex  \
# 21108  11d548da24b2a342000001414e7f330828c6951ee8d33c5a       1076
# 21109  11d548da24b2a342000001414e7f330828c6951ee8d33c5a       1077
# 21130  11d548da24b2a342000001414e7f330828c6951ee8d33c5a       1098
# 21131  11d548da24b2a342000001414e7f330828c6951ee8d33c5a       1099
# 23564  3248dfa1a07f76fe000001416dce75480166920c4c89ca56       1053
#
#          received currency   total     tax  surcharge   source merchant  \
# 21108  1380001461      USD  703.37  115.37        0.0  Amadeus       AA
# 21109  1380001461      USD  703.37  115.37        0.0  Amadeus       AA
# 21130  1380001461      USD  683.37  115.37        0.0  Amadeus       AA
# 21131  1380001461      USD  703.37  115.37        0.0  Amadeus       AA
# 23564  1380526749      USD  629.37  115.37        0.0  Amadeus       DL
#
#       majorcarrierid     ...      refundable triptimestamp  receiveddate  \
# ...

# %%
# Again, I look at the quick stats.

first.describe()
# Out:
#          tripindex      received        total         tax  surcharge  \
# count   276.000000  2.760000e+02   276.000000  276.000000      276.0
# mean   1348.800725  1.381010e+09   726.727464  120.905000        0.0
# std    1335.482706  1.108309e+06   161.349212    5.593849        0.0
# min       6.000000  1.378374e+09   604.370000  101.370000        0.0
# 25%     362.750000  1.379978e+09   648.950000  115.370000        0.0
# 50%    1068.500000  1.381397e+09   673.370000  124.950000        0.0
# 75%    1434.250000  1.381909e+09   725.950000  124.950000        0.0
# max    7093.000000  1.382946e+09  1441.370000  124.950000        0.0
#
#           departure        return  outbounddurationminutes  outboundstops  \
# count  2.760000e+02  2.760000e+02               276.000000     276.000000
# mean   1.384761e+09  1.385734e+09               455.416667       0.949275
# std    2.149657e+06  2.207126e+06               130.783000       0.219833
# ...

# %%
'''On average, I should be looking at paying $726, with the median being $673'''
